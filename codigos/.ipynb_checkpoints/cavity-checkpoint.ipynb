# %%
import Gadget as G
import matplotlib as mpl 
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from matplotlib.mlab import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy           as np
import math            as mt
import statistics      as st
import snap_blocks     as sb
import plots           as im
import plot_format     as pf
import global_fuctions as gf

# %%
#declaration of paths
path_main = '/home/meugenia/Documentos/discos/'
path_snap = path_main+'snaps/'
path_save = path_main +'plots/'

# %%
snap = 'snapshot_160'
ids, x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint = sb.reading_snap(path_snap,snap,0)
ids_s,x_s,y_s,z_s,mass_s,rho_s,vx_s,vy_s,vz_s,bx_s,by_s,bz_s,vrms_s,hsml_s,eint_s = \
sb.sorting_by_ids(ids,x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint)

# %%
r=(x_s*x_s+y_s*y_s)**0.5

# %%
typep   = 'rho'
limx    = [-10,10]
limy    = [-1,1]
limz    = [-10,10]
limrho  = [0,0.0002]
liminte = [-2.15,1]
limvrms = [-3,0]
limr    = [0,10]

sgvar = [x_s, y_s, z_s, r, rho_s, vx_s, vy_s, vz_s, bx_s, by_s, bz_s, vrms_s, eint_s]

var   = [3,1,2,4]
vlims = [limr,limy,limz,limrho]

for i in range(len(var)):
    print vlims[i]
    if i==0:
        _sgvar=gf.sobgroup(sgvar,var[i],vlims[i])
        sgvar=_sgvar
        print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
    else:
        _sgvar=gf.sobgroup([sgvar[0][0],sgvar[1][0],sgvar[2][0],sgvar[3][0],sgvar[4][0],\
                           sgvar[5][0],sgvar[6][0],sgvar[7][0],sgvar[8][0],sgvar[9][0],\
                           sgvar[10][0],sgvar[11][0],sgvar[12][0]], var[i],vlims[i])
        sgvar=_sgvar
        print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
# Out:
# [0, 10]
# 3 0.026673837 9.999921
# [-1, 1]
# 1 -0.99999374 0.99999857
# [-10, 10]
# 2 -9.995226 9.975219
# [0, 0.0002]
# 4 3.1187607e-08 0.00019998013

# %%
sgx,sgy,sgz,sgr,sgrho,sgvx,sgvy,sgvz,sgbx,sgby,sgbz,sgvrms,sgeint = gf.subgroup_all(_sgvar)

# %%
b=sgbx**2+sgby**2+sgbz**2

fig=plt.figure(figsize=(18,24))
ax1= fig.add_subplot(321)
ax1.scatter(sgx,sgz,s=4,c=np.log10(sgrho),cmap='jet',vmin=-8, vmax=-3.9)
ax1.set_title('log rho')
ax2= fig.add_subplot(322)
ax2.scatter(sgx,sgz,s=4,c=np.log10(sgvrms),cmap='jet',vmin=-2,vmax=0.5)
ax2.set_title('log vrms')
ax3= fig.add_subplot(323)
ax3.scatter(sgx,sgz,s=4,c=np.log10(sgeint),cmap='jet',vmin=-2.8,vmax=0.7)
ax3.set_title('log eint')
ax4= fig.add_subplot(324)
ax4.scatter(sgx,sgz,s=4,c=np.log10(abs(sgbz)),cmap='jet',vmin=-18,vmax=3)
ax4.set_title('log BzMOD')
ax4= fig.add_subplot(325)
ax4.scatter(sgx,sgz,s=4,c=np.log10(abs(sgvz)),cmap='jet',vmin=-18,vmax=3)
ax4.set_title('VzMOD')

plt.savefig(path_save+'cavidad/'+snap)

plt.show()

# %%
print 'lim B0'
print np.log10(abs(sgbz.min())),np.log10(sgbz.max())
print 'lim rho'
print np.log10(sgrho.min()),np.log10(sgrho.max())
print 'lim vrms'
print np.log10(sgvrms.min()),np.log10(sgvrms.max())
print 'lim eint'
print np.log10(sgeint.min()),np.log10(sgeint.max())
# Out:
# lim B0
# -0.326897 0.116046
# lim rho
# -8.67238 -3.85
# lim vrms
# -2.12224 0.238403
# lim eint
# -2.84985 0.192735

# %%
typep   = 'rho'
limx    = [-40,40]
limy    = [-40,40]
limz    = [0,30]
limrho  = [0,10**(-3.85)]
liminte = [-2.15,1]
limvrms = [-3,0]
limr    = [-20,20]

sgvar = [x_s, y_s, z_s, r, rho_s, vx_s, vy_s, vz_s, bx_s, by_s, bz_s, vrms_s, eint_s]

var   = [3,1,2,4]
vlims = [limr,limy,limz,limrho]

for i in range(len(var)):
    print vlims[i]
    if i==0:
        _sgvar=gf.sobgroup(sgvar,var[i],vlims[i])
        sgvar=_sgvar
        print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
    else:
        _sgvar=gf.sobgroup([sgvar[0][0],sgvar[1][0],sgvar[2][0],sgvar[3][0],sgvar[4][0],\
                           sgvar[5][0],sgvar[6][0],sgvar[7][0],sgvar[8][0],sgvar[9][0],\
                           sgvar[10][0],sgvar[11][0],sgvar[12][0]], var[i],vlims[i])
        sgvar=_sgvar
        print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
# Out:
# [-20, 20]
# 3 0.026673837 19.999964
# [-40, 40]
# 1 -19.97575 19.994835
# [0, 30]
# 2 3.9519023e-07 29.991098
# [0, 0.0001412537544622754]
# 4 1.3161311e-09 0.00014125256

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(sgx, sgy, sgz, c=np.log10(b), cmap='jet',s=1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
b=sgbx**2+sgby**2+sgbz**2

sgwx=sgy*sgvz-sgz*sgvy
sgwy=sgz*sgvx-sgx*sgvz
sgwz=sgx*sgvy-sgy*sgvx
sgwx=sgwx/(sgx**2+sgy**2)   
sgwy=sgwy/(sgx**2+sgy**2)  
sgwz=sgwz/(sgx**2+sgy**2)

# %%
w=(sgwx**2+sgwy**2+sgwz**2)**0.5
np.log10([w.min(),w.max()])
len(w),len(sgz)
# Out:
# (157959, 157959)

# %%
fig=plt.figure(figsize=(6,6))
plt.scatter(sgx,sgy,c=np.log10(w),s=2,cmap='jet')
plt.show()
