# %%
import Gadget as G
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from matplotlib.mlab import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition, mark_inset)
import numpy           as np
import math            as mt
import statistics      as st
import snap_blocks     as sb
import plots           as im
import plot_format     as pf
import global_fuctions as gf
import mpl_toolkits

# %%
mpl.style.use('classic')
font = {'family': 'sans-serif', 'size': 20, 'sans-serif': ['Helvetica']}
plt.rc('font', **font)
plt.rc('legend', **{'fontsize': 15}) 
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['ytick.minor.size'] = 4
plt.rc('lines', linewidth=3)

# %%
path_main = '/home/meugenia/Documentos/discos/'
path_snap = path_main+'snaps/etacs/'
path_save = path_main +'plots/'

# %%
sindex=["000","001","002","003","004","005","006","007","008","009", 
        "010","020","030","040","050","060","070","080","090","100",
        "110","120","130","140","150","160","170","180","190","200",
        "210","220","230","240","250","260","270","280","290","300",
        "310","320","330","340","350","370"]

# %%
sn=100

# %%
#for sn in range(len(sindex)):
#    if sn!=0:
#        continue
sn=sn+1
snap = 'snapshot_160'
print snap
#pos =G.read_block(path_snap+snap,"POS ",parttype=0)
#eta =G.read_block(path_snap+snap,"EDYN",parttype=0)
mass =G.read_block(path_snap+snap,"MASS",parttype=0)
eint =G.read_block(path_snap+snap,"U   ",parttype=0)
rho  =G.read_block(path_snap+snap,"RHO ",parttype=0)
# Out:
# snapshot_160

# %%
eint.min(),eint.max()
# Out:
# (7.8477456e-07, 6.0328507)

# %%
r = (pos[:,0]**2+pos[:,1]**2)**0.5

# %%
sgr   =   r[(r>=0)&(r<10)&(abs(pos[:,2])<1)&(eta>0)] 
sgeta = eta[(r>=0)&(r<10)&(abs(pos[:,2])<1)&(eta>0)] 
sgz   = pos[:,2][(r>=0)&(r<10)&(abs(pos[:,2])<1)&(eta>0)]

# %%
binnl,medianl,summl,sigmal=st.statistics(100,sgr,sgeta,0,8)
# Out:
# 0.08

# %%
time=int(snap[9:])
plt.scatter(binnl,summl,label='time= '+str(time))
plt.plot(binnl,summl)
plt.ylim(-0.001,0.018)
plt.xlim(0,8)
plt.legend()
plt.savefig(path_save+'profiles/eta/'+snap+'.png',bbox_inches='tight')
plt.show()
