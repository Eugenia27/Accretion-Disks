# %%
import Gadget as G
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from matplotlib.mlab import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition, mark_inset)
import numpy           as np
import math            as mt
import statistics      as st
import snap_blocks     as sb
import plots           as im
import plot_format     as pf
import global_fuctions as gf
import mpl_toolkits

# %%
#plot parameters
mpl.style.use('classic')
font = {'family': 'sans-serif', 'size': 20, 'sans-serif': ['Helvetica']}
plt.rc('font', **font)
plt.rc('legend', **{'fontsize': 15}) 
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['ytick.minor.size'] = 4
plt.rc('lines', linewidth=3)

# %%
#declaration of paths
path_main = '/home/meugenia/Documentos/discos/'
path_snap = path_main+'snaps/'
path_save = path_main +'plots/'

# %%
snap = 'snapshot_160'
ids, x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint = sb.reading_snap(path_snap,snap,0)
ids_s,x_s,y_s,z_s,mass_s,rho_s,vx_s,vy_s,vz_s,bx_s,by_s,bz_s,vrms_s,hsml_s,eint_s = \
sb.sorting_by_ids(ids,x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint)

# %%
r=(x_s*x_s+y_s*y_s)**0.5

# %%
# some snaps
sindex=["000","005", "010","050","060","070","080","090","100","110","120","130","140","150","160","170","180","190","200","250","300","350"]

# %%
# binning in r
typep='vrms'
for sn in range(len(sindex)):
    #if sn!=0:
    #    continue
    snap = 'snapshot_'+sindex[sn]
    print snap
    ids, x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint = sb.reading_snap(path_snap,snap,0)
    ids_s,x_s,y_s,z_s,mass_s,rho_s,vx_s,vy_s,vz_s,bx_s,by_s,bz_s,vrms_s,hsml_s,eint_s = \
    sb.sorting_by_ids(ids,x,y,z,mass,rho,vx,vy,vz,bx,by,bz,vrms,hsml,eint)
    r=(x_s*x_s+y_s*y_s)**0.5
    
    limx    = [-10,10]
    limy    = [-10,10]
    limz    = [-3,3]
    limrho  = [1e-4,np.max(rho_s)]
    liminte = [-2.15,1]
    limvrms = [-3,0]
    limr    = [0,10]
    
    sgvar = [x_s, y_s, z_s, r, rho_s, vx_s, vy_s, vz_s, bx_s, by_s, bz_s, vrms_s, eint_s]
    
    var   = [4,3,2]#1,2,4]
    vlims = [limrho,limr,limz]#limy,limz,limrho]
    
    for i in range(len(var)):
        print vlims[i]
        if i==0:
            _sgvar=gf.sobgroup(sgvar,var[i],vlims[i])
            sgvar=_sgvar
            print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
        else:
            _sgvar=gf.sobgroup([sgvar[0][0],sgvar[1][0],sgvar[2][0],sgvar[3][0],sgvar[4][0],\
                               sgvar[5][0],sgvar[6][0],sgvar[7][0],sgvar[8][0],sgvar[9][0],\
                               sgvar[10][0],sgvar[11][0],sgvar[12][0]], var[i],vlims[i])
            sgvar=_sgvar
            print var[i], _sgvar[var[i]][0].min(), _sgvar[var[i]][0].max()
            
            
    sgx,sgy,sgz,sgr,sgrho,sgvx,sgvy,sgvz,sgbx,sgby,sgbz,sgvrms,sgeint = gf.subgroup_all(_sgvar) 
    
    
    sgzn = (sgz+abs(sgz.min()))/(sgz.max()-sgz.min())
    
    binn,median,summ,sigma=st.statistics(100,sgzn,sgvrms,0,1)
    binnl,medianl,summl,sigmal=st.statistics(100,sgzn,np.log10(sgvrms),0,1)
       
    slimz=str(limz[1])    
        
    spdfl=path_save   +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/pdf/log/___log'+typep+'_'+snap
    spngl=path_save   +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/png/log/___log'+typep+'_'+snap
    spdflsp=path_save +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/pdf/subplot/log/___log'+typep+'_'+snap
    spnglsp=path_save +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/png/subplot/log/___log'+typep+'_'+snap
    spdfnl=path_save  +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/pdf/nolog/___'+typep+'_'+snap
    spngnl=path_save  +'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/png/nolog/___'+typep+'_'+snap
    spdfnlsp=path_save+'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/pdf/subplot/___nolog/'+typep+'_'+snap
    spngnlsp=path_save+'profiles/'+typep+'/znbin100_r0to10_zabs'+slimz+'_median/png/subplot/___nolog/'+typep+'_'+snap
      
    
    fig=plt.figure(figsize=(10,10))
    ax1=fig.add_subplot(111)
    im.plot_profile(ax1,binn,summ,sigma,[0,1],[-0.005,0.1],['(z+abs(zmin))/deltaz','vrms'],['media$\pm \sigma$','media'],snap,spdfnl,spngnl,1)
   # 
    #fig=plt.figure(figsize=(7,7))
    #ax1=fig.add_subplot(111)
    #im.plot_profile_with_subplot(ax1,binn,median,sigma,[-1.7,1.7],[-0.01,0.035],[0.5,8],[0,0.00045],['z',r'$\rho$'],['median$\pm \sigma$','median'],snap,spdfnlsp,spngnlsp,1)
    
    fig=plt.figure(figsize=(10,10))
    ax1=fig.add_subplot(111)
    im.plot_profile(ax1,binnl,summl,sigmal,[0,1],[-2.15,-1],['(z+abs(zmin))/deltaz',r'log vrms'],['media$\pm \sigma$','media'],snap,spdfl,spngl,1)
    
    #fig=plt.figure(figsize=(7,7))
    #ax1=fig.add_subplot(111)
    #im.plot_profile_with_subplot(ax1,binnl,medianl,sigmal,[-1.7,1.7],[-6,0],[0.5,8],[-5.4, -2],['z',r'log $\rho$'],['median$\pm \sigma$','median'],snap,spdflsp,spnglsp,1)
# Out:
# snapshot_000
# [0.0001, 0.11548974]
# 4 0.00010000002 0.1152341
# [0, 10]
# 3 0.026714245 8.410401
# [-3, 3]
# 2 -1.2304952 1.14362
# 0.01
# 0.01
# snapshot_005
# [0.0001, 0.08646248]
# 4 0.000100000514 0.08538173
# [0, 10]
# 3 0.035719473 8.399697
# [-3, 3]
# 2 -1.1146315 1.133052
# 0.01
# 0.01
# snapshot_010
# [0.0001, 0.104011655]
# 4 0.0001000014 0.10338723
# [0, 10]
# 3 0.08593109 8.364176
# [-3, 3]
# 2 -1.1596234 1.2247059
# 0.01
# 0.01
# snapshot_050
# [0.0001, 0.087246776]
# 4 0.00010000002 0.08606724
# [0, 10]
# 3 0.20339549 8.090641
# [-3, 3]
# 2 -1.2678263 1.2955115
# 0.01
# 0.01
# snapshot_060
# [0.0001, 0.16131881]
# 4 0.00010000066 0.15992463
# [0, 10]
# 3 0.029620761 7.8986044
# [-3, 3]
# 2 -1.0008081 1.0200435
# 0.01
# 0.01
# snapshot_070
# [0.0001, 0.19522436]
# 4 0.00010000019 0.19393215
# [0, 10]
# 3 0.24965027 7.920057
# [-3, 3]
# 2 -1.4552405 1.5163714
# 0.01
# 0.01
# snapshot_080
# [0.0001, 0.23652133]
# 4 0.00010000152 0.23258224
# [0, 10]
# ...

# %%
plt.scatter(sgz,np.log10(sgrho),marker='.',edgecolor="none",s=0.1,color='gray')
plt.plot(binn,np.log10(median),marker='s',color='black')
plt.plot(binn,np.log10(summ),marker='s',color='green')
plt.show()
