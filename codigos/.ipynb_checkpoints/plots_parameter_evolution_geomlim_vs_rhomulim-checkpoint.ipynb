# %%
import Gadget as G
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from matplotlib.mlab import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition, mark_inset)
import numpy           as np
import math            as mt
import statistics      as st
import snap_blocks     as sb
import plots           as im
import plot_format     as pf
import global_fuctions as gf
import mpl_toolkits

# %%
mpl.style.use('classic')
font = {'family': 'sans-serif', 'size': 25, 'sans-serif': ['Helvetica']}
plt.rc('font', **font)
plt.rc('legend', **{'fontsize': 22}) 
plt.rcParams['axes.linewidth'] = 1.0
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['ytick.minor.size'] = 4
plt.rc('lines', linewidth=3)

# %%
path_main = '/home/meugenia/Documentos/discos/'
par_mef   = 'regiones/disco/propiedades_vs_t/unidades_correctas/mef/'
par_mc    = 'regiones/disco/propiedades_vs_t/unidades_correctas/mc/'
par_crun  = 'regiones/disco/propiedades_vs_t/unidades_correctas/control/'
path_snap = path_main+'snaps/'
path_save = path_main +'plots/'

# %%
# evoluscion de parametros segun mari cecere
time = np.loadtxt(path_main+par_mc+'mc_evo_rho' , usecols=[0], unpack=True)
tmediarho   ,  tmedianarho   ,  tsigmarho   ,tpercentil25rho   ,tpercentil75rho   = np.loadtxt(path_main+par_mc+'mc_evo_rho'  , usecols=[1,2,3,4,5], unpack=True)
tmediaeint  ,  tmedianaeint  ,  tsigmaeint  ,tpercentil25eint  ,tpercentil75eint  = np.loadtxt(path_main+par_mc+'mc_evo_eint' , usecols=[1,2,3,4,5], unpack=True)
tmediavrms  ,  tmedianavrms  ,  tsigmavrms  ,tpercentil25vrms  ,tpercentil75vrms  = np.loadtxt(path_main+par_mc+'mc_evo_vrms' , usecols=[1,2,3,4,5], unpack=True)
tmediabx    ,  tmedianabx    ,  tsigmabx    ,tpercentil25bx    ,tpercentil75bx    = np.loadtxt(path_main+par_mc+'mc_evo_bx'   , usecols=[1,2,3,4,5], unpack=True)
tmediaby    ,  tmedianaby    ,  tsigmaby    ,tpercentil25by    ,tpercentil75by    = np.loadtxt(path_main+par_mc+'mc_evo_by'   , usecols=[1,2,3,4,5], unpack=True)
tmediabz    ,  tmedianabz    ,  tsigmabz    ,tpercentil25bz    ,tpercentil75bz    = np.loadtxt(path_main+par_mc+'mc_evo_bz'   , usecols=[1,2,3,4,5], unpack=True)
tmediabr    ,  tmedianabr    ,  tsigmabr    ,tpercentil25br    ,tpercentil75br    = np.loadtxt(path_main+par_mc+'mc_evo_br'   , usecols=[1,2,3,4,5], unpack=True)
tmediabphi  ,  tmedianabphi  ,  tsigmabphi  ,tpercentil25bphi  ,tpercentil75bphi  = np.loadtxt(path_main+par_mc+'mc_evo_bphi' , usecols=[1,2,3,4,5], unpack=True)
tmediabzc   ,  tmedianabzc   ,  tsigmabzc   ,tpercentil25bzc   ,tpercentil75bzc   = np.loadtxt(path_main+par_mc+'mc_evo_bzc'  , usecols=[1,2,3,4,5], unpack=True)              
tmediabrc   ,  tmedianabrc   ,  tsigmabrc   ,tpercentil25brc   ,tpercentil75brc   = np.loadtxt(path_main+par_mc+'mc_evo_brc'  , usecols=[1,2,3,4,5], unpack=True)           
tmediabphic ,  tmedianabphic ,  tsigmabphic ,tpercentil25bphic ,tpercentil75bphic = np.loadtxt(path_main+par_mc+'mc_evo_bphic', usecols=[1,2,3,4,5], unpack=True)             
tmediabc    ,  tmedianabc    ,  tsigmabc    ,tpercentil25bc    ,tpercentil75bc    = np.loadtxt(path_main+par_mc+'mc_evo_bc'   , usecols=[1,2,3,4,5], unpack=True)               
tmediaemagz ,  tmedianaemagz ,  tsigmaemagz ,tpercentil25emagz ,tpercentil75emagz = np.loadtxt(path_main+par_mc+'mc_evo_emagz', usecols=[1,2,3,4,5], unpack=True)              
tmediaemagr ,  tmedianaemagr ,  tsigmaemagr ,tpercentil25emagr ,tpercentil75emagr = np.loadtxt(path_main+par_mc+'mc_evo_emagr', usecols=[1,2,3,4,5], unpack=True)           
tmediaemagp ,  tmedianaemagp ,  tsigmaemagp ,tpercentil25emagp ,tpercentil75emagp = np.loadtxt(path_main+par_mc+'mc_evo_emagp', usecols=[1,2,3,4,5], unpack=True)                     

tmediaecin  ,   tmedianaecin ,  tsigmaecin  ,tpercentil25ecin  ,tpercentil75ecin  = np.loadtxt(path_main+par_mc+'mc_evo_ecin', usecols=[1,2,3,4,5], unpack=True) 
tmediaT     ,   tmedianaT    ,  tsigmaT     ,tpercentil25T     ,tpercentil75T     = np.loadtxt(path_main+par_mc+'mc_evo_T'   , usecols=[1,2,3,4,5], unpack=True) 
tmediaemag  ,   tmedianaemag ,  tsigmaemag  ,tpercentil25emag  ,tpercentil75emag  = np.loadtxt(path_main+par_mc+'mc_evo_emag', usecols=[1,2,3,4,5], unpack=True) 
tmediaetot  ,   tmedianaetot ,  tsigmaetot  ,tpercentil25etot  ,tpercentil75etot  = np.loadtxt(path_main+par_mc+'mc_evo_etot', usecols=[1,2,3,4,5], unpack=True)

# %%
# evolucion de parametros segun maru ferraro
time = np.loadtxt(path_main+par_mef+'mef_evo_rho' , usecols=[0], unpack=True)
mtmediarho   ,  mtmedianarho   ,  mtsigmarho   ,mtpercentil25rho   ,mtpercentil75rho   = np.loadtxt(path_main+par_mef+'mef_evo_rho'  , usecols=[1,2,3,4,5], unpack=True)
mtmediaeint  ,  mtmedianaeint  ,  mtsigmaeint  ,mtpercentil25eint  ,mtpercentil75eint  = np.loadtxt(path_main+par_mef+'mef_evo_eint' , usecols=[1,2,3,4,5], unpack=True)
mtmediavrms  ,  mtmedianavrms  ,  mtsigmavrms  ,mtpercentil25vrms  ,mtpercentil75vrms  = np.loadtxt(path_main+par_mef+'mef_evo_vrms' , usecols=[1,2,3,4,5], unpack=True)
mtmediabx    ,  mtmedianabx    ,  mtsigmabx    ,mtpercentil25bx    ,mtpercentil75bx    = np.loadtxt(path_main+par_mef+'mef_evo_bx'   , usecols=[1,2,3,4,5], unpack=True)
mtmediaby    ,  mtmedianaby    ,  mtsigmaby    ,mtpercentil25by    ,mtpercentil75by    = np.loadtxt(path_main+par_mef+'mef_evo_by'   , usecols=[1,2,3,4,5], unpack=True)
mtmediabz    ,  mtmedianabz    ,  mtsigmabz    ,mtpercentil25bz    ,mtpercentil75bz    = np.loadtxt(path_main+par_mef+'mef_evo_bz'   , usecols=[1,2,3,4,5], unpack=True)
mtmediabr    ,  mtmedianabr    ,  mtsigmabr    ,mtpercentil25br    ,mtpercentil75br    = np.loadtxt(path_main+par_mef+'mef_evo_br'   , usecols=[1,2,3,4,5], unpack=True)
mtmediabphi  ,  mtmedianabphi  ,  mtsigmabphi  ,mtpercentil25bphi  ,mtpercentil75bphi  = np.loadtxt(path_main+par_mef+'mef_evo_bphi' , usecols=[1,2,3,4,5], unpack=True)
mtmediabzc   ,  mtmedianabzc   ,  mtsigmabzc   ,mtpercentil25bzc   ,mtpercentil75bzc   = np.loadtxt(path_main+par_mef+'mef_evo_bzc'  , usecols=[1,2,3,4,5], unpack=True)              
mtmediabrc   ,  mtmedianabrc   ,  mtsigmabrc   ,mtpercentil25brc   ,mtpercentil75brc   = np.loadtxt(path_main+par_mef+'mef_evo_brc'  , usecols=[1,2,3,4,5], unpack=True)           
mtmediabphic ,  mtmedianabphic ,  mtsigmabphic ,mtpercentil25bphic ,mtpercentil75bphic = np.loadtxt(path_main+par_mef+'mef_evo_bphic', usecols=[1,2,3,4,5], unpack=True)             
mtmediabc    ,  mtmedianabc    ,  mtsigmabc    ,mtpercentil25bc    ,mtpercentil75bc    = np.loadtxt(path_main+par_mef+'mef_evo_bc'   , usecols=[1,2,3,4,5], unpack=True)               
mtmediaemagz ,  mtmedianaemagz ,  mtsigmaemagz ,mtpercentil25emagz ,mtpercentil75emagz = np.loadtxt(path_main+par_mef+'mef_evo_emagz', usecols=[1,2,3,4,5], unpack=True)              
mtmediaemagr ,  mtmedianaemagr ,  mtsigmaemagr ,mtpercentil25emagr ,mtpercentil75emagr = np.loadtxt(path_main+par_mef+'mef_evo_emagr', usecols=[1,2,3,4,5], unpack=True)           
mtmediaemagp ,  mtmedianaemagp ,  mtsigmaemagp ,mtpercentil25emagp ,mtpercentil75emagp = np.loadtxt(path_main+par_mef+'mef_evo_emagp', usecols=[1,2,3,4,5], unpack=True)                     

mtmediaecin  ,  mtmedianaecin  ,  mtsigmaecin  ,mtpercentil25ecin  ,mtpercentil75ecin  = np.loadtxt(path_main+par_mef+'mef_evo_ecin' , usecols=[1,2,3,4,5], unpack=True) 
mtmediaT     ,  mtmedianaT     ,  mtsigmaT     ,mtpercentil25T     ,mtpercentil75T     = np.loadtxt(path_main+par_mef+'mef_evo_T'    , usecols=[1,2,3,4,5], unpack=True) 
mtmediaemag  ,  mtmedianaemag  ,  mtsigmaemag  ,mtpercentil25emag  ,mtpercentil75emag  = np.loadtxt(path_main+par_mef+'mef_evo_emag' , usecols=[1,2,3,4,5], unpack=True) 
mtmediaetot  ,  mtmedianaetot  ,  mtsigmaetot  ,mtpercentil25etot  ,mtpercentil75etot  = np.loadtxt(path_main+par_mef+'mef_evo_etot' , usecols=[1,2,3,4,5], unpack=True)

# %%
# evolucion de parametros controlrun
ctime = np.loadtxt(path_main+par_crun+'mef_evo_rho' , usecols=[0], unpack=True)
ctmediarho   ,  ctmedianarho   ,  ctsigmarho   ,ctpercentil25rho   ,ctpercentil75rho   = np.loadtxt(path_main+par_crun+'mef_evo_rho'  , usecols=[1,2,3,4,5], unpack=True)
ctmediaeint  ,  ctmedianaeint  ,  ctsigmaeint  ,ctpercentil25eint  ,ctpercentil75eint  = np.loadtxt(path_main+par_crun+'mef_evo_eint' , usecols=[1,2,3,4,5], unpack=True)
ctmediavrms  ,  ctmedianavrms  ,  ctsigmavrms  ,ctpercentil25vrms  ,ctpercentil75vrms  = np.loadtxt(path_main+par_crun+'mef_evo_vrms' , usecols=[1,2,3,4,5], unpack=True)
ctmediaecin  ,  ctmedianaecin  ,  ctsigmaecin  ,ctpercentil25ecin  ,ctpercentil75ecin  = np.loadtxt(path_main+par_crun+'mef_evo_ecin' , usecols=[1,2,3,4,5], unpack=True) 
ctmediaT     ,  ctmedianaT     ,  ctsigmaT     ,ctpercentil25T     ,ctpercentil75T     = np.loadtxt(path_main+par_crun+'mef_evo_T'    , usecols=[1,2,3,4,5], unpack=True) 
ctmediaetot  ,  ctmedianaetot  ,  ctsigmaetot  ,ctpercentil25etot  ,ctpercentil75etot  = np.loadtxt(path_main+par_crun+'mef_evo_etot' , usecols=[1,2,3,4,5], unpack=True)

# %%
c1='#FFBE3A' #naranja
c2='#4BACFF' #celeste
c3='#05A41A' #verde

# %%
fig=plt.figure(figsize=(10,10))
ax= fig.add_subplot(111)

plt.plot(time,tmedianaemagr,label='EB$_r$', color=c3,ls='--')
plt.fill_between(time,tpercentil25emagr,tpercentil75emagr,edgecolor=c3,hatch='//',facecolor='none',alpha=0.2)
plt.plot(time,tmedianaemagp,label=r'EB$_{\phi}$', color=c1,ls='--')
plt.fill_between(time,tpercentil25emagp,tpercentil75emagp,edgecolor=c1,hatch='//',facecolor='none',alpha=0.2)
plt.plot(time,tmedianaemagz,label='EB$_z$',color=c2,ls='--')
plt.fill_between(time,tpercentil25emagz,tpercentil75emagz,edgecolor=c2,hatch='//',facecolor='none',alpha=0.2)

plt.plot(time,mtmedianaemagr,label='EB$_r$', color=c3)
plt.fill_between(time,mtpercentil25emagr,mtpercentil75emagr,edgecolor=c3,facecolor=c3,alpha=0.2)
plt.plot(time,mtmedianaemagp,label=r'EB$_{\phi}$', color=c1)
plt.fill_between(time,mtpercentil25emagp,mtpercentil75emagp,edgecolor=c1,facecolor=c1,alpha=0.2)
plt.plot(time,mtmedianaemagz,label='EB$_z$',color=c2,)
plt.fill_between(time,mtpercentil25emagz,mtpercentil75emagz,edgecolor=c2,facecolor=c2,alpha=0.2)

plt.legend(loc='lower right', frameon=False,ncol=2)
plt.title('Med + InterQuartileRange')
plt.xlim(-10,350)
plt.yscale('log')

plt.text(0.6, 0.24,"Geom \nLimits", ha='center', va='center', transform=ax.transAxes,color="black", fontsize=14)
plt.text(0.85, 0.24,"Rho+U \nLimits", ha='center', va='center', transform=ax.transAxes,color="black", fontsize=14)

ax.minorticks_on()
plt.xlabel('t')
plt.savefig(path_save+'disco/componentes_emag_comp_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
fig=plt.figure(figsize=(10,10))
ax= fig.add_subplot(111)

plt.plot(time,tmediaemagr,label='EB$_r$', color=c3,ls='--')
plt.fill_between(time,tmediaemagr - tsigmaemagr,tmediaemagr + tsigmaemagr,edgecolor=c3,hatch='//',facecolor='none',alpha=0.2)
#plt.fill_between(time,tpercentil25emagr,tpercentil75emagr,edgecolor=c3,hatch='//',facecolor='none',alpha=0.2)
#plt.plot(time,tmedianaemagp,label=r'EB$_{\phi}$', color=c1,ls='--')
#plt.fill_between(time,tpercentil25emagp,tpercentil75emagp,edgecolor=c1,hatch='//',facecolor='none',alpha=0.2)
#plt.plot(time,tmedianaemagz,label='EB$_z$',color=c2,ls='--')
#plt.fill_between(time,tpercentil25emagz,tpercentil75emagz,edgecolor=c2,hatch='//',facecolor='none',alpha=0.2)

#plt.plot(time,mtmedianaemagr,label='EB$_r$', color=c3)
#plt.fill_between(time,mtpercentil25emagr,mtpercentil75emagr,edgecolor=c3,facecolor=c3,alpha=0.2)
#plt.plot(time,mtmedianaemagp,label=r'EB$_{\phi}$', color=c1)
#plt.fill_between(time,mtpercentil25emagp,mtpercentil75emagp,edgecolor=c1,facecolor=c1,alpha=0.2)
#plt.plot(time,mtmedianaemagz,label='EB$_z$',color=c2,)
#plt.fill_between(time,mtpercentil25emagz,mtpercentil75emagz,edgecolor=c2,facecolor=c2,alpha=0.2)

#plt.legend(loc='lower right', frameon=False,ncol=2)
#plt.title('Med + InterQuartileRange')
plt.xlim(-10,350)
#plt.yscale('log')

#plt.text(0.6, 0.24,"Geom \nLimits", ha='center', va='center', transform=ax.transAxes,color="black", fontsize=14)
#plt.text(0.85, 0.24,"Rho+U \nLimits", ha='center', va='center', transform=ax.transAxes,color="black", fontsize=14)

#ax.minorticks_on()
#plt.xlabel('t')
#plt.savefig(path_save+'disco/componentes_emag_comp_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(time,tmedianarho ,label=r'$\rho$ medians geom limits',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianarho,label=r'$\rho$ medians rho+u limits ',marker='s',mfc='none', color=c1)
plt.fill_between(time,tpercentil25rho ,tpercentil75rho ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25rho,mtpercentil75rho,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,tmediarho-tsigmarho,tmediarho+tsigmarho,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediarho-mtsigmarho,mtmediarho+mtsigmarho,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='lower left', frameon=False)
plt.title('EVO DENSITY - DISC')
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
plt.savefig(path_save+'disco/rho_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(time,tmedianaeint ,label=r'$U$ medians geom limits',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaeint,label=r'$U$ medians rho+u limits ',marker='s',mfc='none', color=c1)
plt.fill_between(time,tpercentil25eint ,tpercentil75eint ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25eint,mtpercentil75eint,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,tmediaeint-tsigmaeint,tmediaeint+tsigmaeint,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaeint-mtsigmaeint,mtmediaeint+mtsigmaeint,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='lower left', frameon=False)
plt.title('EVO INTENERGY - DISC')
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
plt.savefig(path_save+'disco/eint_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(time,tmedianaT ,label=r'$T$ medians geom limits',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaT,label=r'$T$ medians rho+u limits ',marker='s',mfc='none', color=c1)
plt.fill_between(time,tpercentil25T ,tpercentil75T ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25T,mtpercentil75T,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,tmediaT-tsigmaT,tmediaT+tsigmaT,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaT-mtsigmaT,mtmediaT+mtsigmaT,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='upper right', frameon=False)
plt.title('EVO TEMP - DISC')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
plt.savefig(path_save+'disco/T_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(time,tmedianaecin ,label=r'$ECIN$ medians geom limits',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaecin,label=r'$ECIN$ medians rho+u limits ',marker='s',mfc='none', color=c1)
plt.fill_between(time,tpercentil25ecin ,tpercentil75ecin ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25ecin,mtpercentil75ecin,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,tmediaecin-tsigmaecin,tmediaecin+tsigmaecin,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaecin-mtsigmaecin,mtmediaecin+mtsigmaecin,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='upper right', frameon=False)
plt.title('EVO ECIN - DISC')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
plt.savefig(path_save+'disco/ECIN_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(ctime,ctmedianarho ,label=r'$\rho$ control',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianarho,label=r'$\rho$ etacs',marker='s',mfc='none', color=c1)
plt.fill_between(ctime,ctpercentil25rho ,ctpercentil75rho ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25rho,mtpercentil75rho,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(ctime,ctmediarho-ctsigmarho,ctmediarho+ctsigmarho,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediarho-mtsigmarho,mtmediarho+mtsigmarho,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='lower left', frameon=False)
plt.title('EVO DENSITY - DISC')
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
#plt.savefig(path_save+'disco/rho_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(ctime,ctmedianaeint ,label=r'$U$ control',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaeint,label=r'$U$ etacs ',marker='s',mfc='none', color=c1)
plt.fill_between(ctime,ctpercentil25eint ,ctpercentil75eint ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25eint,mtpercentil75eint,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(ctime,ctmediaeint-ctsigmaeint,ctmediaeint+ctsigmaeint,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaeint-mtsigmaeint,mtmediaeint+mtsigmaeint,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='lower left', frameon=False)
plt.title('EVO INTENERGY - DISC')
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
#plt.savefig(path_save+'disco/eint_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(ctime,ctmedianaT ,label=r'$T$ control',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaT,label=r'$T$ etacs',marker='s',mfc='none', color=c1)
plt.fill_between(ctime,ctpercentil25T ,ctpercentil75T ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25T,mtpercentil75T,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(ctime,ctmediaT-ctsigmaT,ctmediaT+ctsigmaT,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaT-mtsigmaT,mtmediaT+mtsigmaT,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='upper right', frameon=False)
plt.title('EVO TEMP - DISC')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
#plt.savefig(path_save+'disco/T_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(ctime,ctmedianaecin ,label=r'$ECIN$ control',marker='s',mfc='none', color=c3)
plt.plot(time,mtmedianaecin,label=r'$ECIN$ etacs',marker='s',mfc='none', color=c1)
plt.fill_between(ctime,ctpercentil25ecin ,ctpercentil75ecin ,edgecolor=c3,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(time,mtpercentil25ecin,mtpercentil75ecin,edgecolor=c1,hatch='//',facecolor='none',alpha=0.7)
plt.fill_between(ctime,ctmediaecin-ctsigmaecin,ctmediaecin+ctsigmaecin,edgecolor=c3,facecolor=c3,alpha=0.18)
plt.fill_between(time,mtmediaecin-mtsigmaecin,mtmediaecin+mtsigmaecin,edgecolor=c1,facecolor=c1,alpha=0.3)
plt.legend(loc='upper right', frameon=False)
plt.title('EVO ECIN - DISC')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.xlim(0,350)
#plt.ylim(1e-14,1.41e-14)
#plt.yscale('log')
plt.xlabel('t')
#plt.savefig(path_save+'disco/ECIN_vs_t.pdf', format='pdf', dpi=1500,bbox_inches='tight')
plt.show()
